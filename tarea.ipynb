# %% [markdown]
# tarea numero 1
# diego sanchez

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

bd = "bank-full.csv"
names = ['age', 'job', 'marital', 'education', 'default', 'balance', 'housing', 'loan', 'contact','day','month','duration',
        'campaign','pdays','previous','poutcome','y']
data = pd.read_csv(bd, names=names)

# %%
# age: edad de entrevistado
# job: tipo de trabajo "admin.","unknown","unemployed","management","housemaid","entrepreneur","student",
# marital: estado civel "married","divorced","single"
#education: grado de educacion "unknown","secondary","primary","tertiary"
#default:  tiene el crédito por defecto? "yes","no"
#balance: saldo medio anual numero tipo de dato
#housing: tiene prestamo de vivienda "yes","no"
#loan: tiene prestamo personal? "yes","no"
#contact: comunicación de contacto "unknown","telephone","cellular"
#day: último día de contacto del mesn numeros de dias
#month: último contacto mes del año "jan", "feb", "mar", ..., "nov", "dec"
#duration: Duración del último contacto, en segundos. numero
#campaign: cantidad de veces contactado, numero
#pdays: la cantidad de días que pasaron después de que el cliente 
#fue contactado por última vez desde una campaña anterior 
#(numérico, -1 significa que el cliente no fue contactado previamente)
#previous: número de contactos realizados antes de esta campaña y para este cliente (numérico)
#poutcome: Resultado de la campaña de marketing anterior. "unknown","other","failure","success"
#y: has the client subscribed a term deposit? (binary: "yes","no")
data
# Out:
#        age            job   marital  education default  balance housing loan  \
# 0       58     management   married   tertiary      no     2143     yes   no
# 1       44     technician    single  secondary      no       29     yes   no
# 2       33   entrepreneur   married  secondary      no        2     yes  yes
# 3       47    blue-collar   married    unknown      no     1506     yes   no
# 4       33        unknown    single    unknown      no        1      no   no
# 5       35     management   married   tertiary      no      231     yes   no
# 6       28     management    single   tertiary      no      447     yes  yes
# 7       42   entrepreneur  divorced   tertiary     yes        2     yes   no
# 8       58        retired   married    primary      no      121     yes   no
# 9       43     technician    single  secondary      no      593     yes   no
# 10      41         admin.  divorced  secondary      no      270     yes   no
# ...

# %% [markdown]
# analizando los datos los quise agrupar según en tipo, decidí agruparlos por el estado civil y ver si hay diferencias.

# %%
# promedio de edad segun "marital "
single_pro_edad =data[data['marital']=='single']['age'].mean()
married_pro_edad =data[data['marital']=='married']['age'].mean()
divorced_pro_edad = data[data['marital']=='divorced']['age'].mean()

print("promedio de edad de soltero: ",single_pro_edad)
print("promedio de edad de casado: ",married_pro_edad)
print("promedio de edad de divorciado: ",divorced_pro_edad)
# Out:
# promedio de edad de soltero:  33.7034401876466
# promedio de edad de casado:  43.40809877269053
# promedio de edad de divorciado:  45.78298444401767

# %%
#cantidad de prestamos de vivvienda
nro_prestamo_vivi=data[data['housing']=='yes']['housing'].count()
nro_prestamo_personal=data[data['loan']=='yes']['loan'].count()
print("cantidad de prestamos de vivienda: ",nro_prestamo_vivi)
print("cantidad de prestamos de personal: ",nro_prestamo_personal)
# Out:
# cantidad de prestamos de vivienda:  25130
# cantidad de prestamos de personal:  7244

# %%
#pomedio de edad de persona con prestamo 
promedio_edad_pres_vivi=data[data['housing']=='yes']['age'].mean()
promedio_edad_pres_per=data[data['loan']=='yes']['age'].mean()
print("promedio de edad prestamo vivienda: ",promedio_edad_pres_vivi)
print("promedio de edad prestamo personal: ",promedio_edad_pres_per)
# Out:
# promedio de edad prestamo vivienda:  39.175288499801034
# promedio de edad prestamo personal:  40.55563224737714

# %%
#cantidad segun estado civil
nor_single=data[data['marital']=='single']['marital'].count()
nor_married=data[data['marital']=='married']['marital'].count()
nor_divorced=data[data['marital']=='divorced']['marital'].count()
por= (nor_single/45211)*100
print("cantiad de soltero: ",nor_single," ",por,"%")
por= (nor_married/45211)*100
print("cantiad de casado: ",nor_married," ",por,"%")
por= (nor_divorced/45211)*100
print("cantiad de divorciado: ",nor_divorced," ",por,"%")
total=nor_single+nor_married+nor_divorced
#cantidad de persona con prestamo vivienda segun estado civil
nro_single_pre_vivi=data[(data['housing']=='yes') & (data['marital']=='single')]['marital'].count()
nro_married_pre_vivi=data[(data['housing']=='yes') & (data['marital']=='married')]['marital'].count()
nro_divorced_pre_vivi=data[(data['housing']=='yes') & (data['marital']=='divorced')]['marital'].count()
por_pre_ci=(nro_single_pre_vivi/nor_single)*100
print("soltero con prestamo vivienda: ",nro_single_pre_vivi," ",por_pre_ci,"%")
por_pre_ci=(nro_married_pre_vivi/nor_married)*100
print("casado con prestamo vivienda: ",nro_married_pre_vivi," ",por_pre_ci,"%")
por_pre_ci=(nro_divorced_pre_vivi/nor_divorced)*100
print("divorciado con prestamo vivienda: ",nro_divorced_pre_vivi," ",por_pre_ci,"%")
#cantidad de persona con prestamo personal segun estado civil
nro_single_pre_pe=data[(data['loan']=='yes') & (data['marital']=='single')]['marital'].count()
nro_married_pre_pe=data[(data['loan']=='yes') & (data['marital']=='married')]['marital'].count()
nro_divorced_pre_pe=data[(data['loan']=='yes') & (data['marital']=='divorced')]['marital'].count()
por_pre_ci=(nro_single_pre_pe/nor_single)*100
print("soltero con prestamo personal: ",nro_single_pre_pe," ",por_pre_ci,"%")
por_pre_ci=(nro_married_pre_pe/nor_married)*100
print("casado con prestamo personal: ",nro_married_pre_pe," ",por_pre_ci,"%")
por_pre_ci=(nro_divorced_pre_pe/nor_divorced)*100
print("divorciado con prestamo personal: ",nro_divorced_pre_pe," ",por_pre_ci,"%")
# Out:
# cantiad de soltero:  12790   28.28957554577426 %
# cantiad de casado:  27214   60.193315785981284 %
# cantiad de divorciado:  5207   11.517108668244454 %
# soltero con prestamo vivienda:  6902   53.96403440187647 %
# casado con prestamo vivienda:  15321   56.29822885279635 %
# divorciado con prestamo vivienda:  2907   55.82869214518917 %
# soltero con prestamo personal:  1663   13.002345582486319 %
# casado con prestamo personal:  4660   17.123539354743883 %
# divorciado con prestamo personal:  921   17.687728058382945 %

# %%
#cantodad con deposito bancarrio
nro_y=data[data['y']=='yes']['y'].count()
nro_y_f=data[data['y']=='no']['y'].count()
print("cantidad con deposito bancario: ",nro_y," ",(nro_y/45211)*100,"%")
print("cantidad sin deposito bancario: ",nro_y_f," ",(nro_y_f/45211)*100,"%")
# Out:
# cantidad con deposito bancario:  5289   11.698480458295547 %
# cantidad sin deposito bancario:  39922   88.30151954170445 %

# %%
#se filtra segun y = yes y muestra el promedio de edad segun estado civil
filas_y=data[data['y']=='yes']#obtiene datos de los y = yes
single_pro_edad =filas_y[filas_y['marital']=='single']['age'].count()
married_pro_edad =filas_y[filas_y['marital']=='married']['age'].count()
divorced_pro_edad = filas_y[filas_y['marital']=='divorced']['age'].count()

print("cantidad de yes = y de soltero con y = yes: ",single_pro_edad)
print("cantidad de yes = y de casado con y = yes: ",married_pro_edad)
print("cantidad de yes = y de divorciado con y = yes: ",divorced_pro_edad)
# Out:
# cantidad de yes = y de soltero con y = yes:  1912
# cantidad de yes = y de casado con y = yes:  2755
# cantidad de yes = y de divorciado con y = yes:  622

# %%
#cantidad de y = yes logrados en la campaña anterior
can_ante=filas_y[filas_y['poutcome']=='success']['poutcome'].count()
can_ante_f=filas_y[filas_y['poutcome']=='failure']['poutcome'].count()
print("cantidad lograda campaña anteror: ",can_ante)
print("cantidad fallida campaña anteror: ",can_ante_f)
# Out:
# cantidad lograda campaña anteror:  978
# cantidad fallida campaña anteror:  618

# %%
#cantidad de y = yes campaña anterir segun estado civil
single_y_ante= filas_y[(filas_y['poutcome']=='success') & (filas_y['marital']=='single')]['age'].count()
married_y_ante= filas_y[(filas_y['poutcome']=='success') & (filas_y['marital']=='married')]['age'].count()
divorced_y_ante= filas_y[(filas_y['poutcome']=='success') & (filas_y['marital']=='divorced')]['age'].count()
print(single_y_ante)
print(married_y_ante)
print(divorced_y_ante)


df = pd.DataFrame({'cantida de y = yes campaña anterior': [single_y_ante, married_y_ante , divorced_y_ante]},index=['single', 'married', 'divorced'])
plot = df.plot.pie(y='cantida de y = yes campaña anterior', figsize=(6, 5),autopct='%1.1f%%')
# Out:
# 338
# 547
# 93

# %% [markdown]
# En estos gráficos filtro por estado civil "marital" (single,married,divorced), después a cada tipo se grafica según la edad en el eje x y la cantidad de veces contactado en el eje y.
# en la primera grafica se puede ver que persona soltera de entre 20 a 30 años fueron los mas contactados a diferencia de la grafica 2 y 3 que las personas entre 40 50 años fueron mas contactados.

# %%
data_sorted=data.sort_values(by='age')

fig, ax = plt.subplots(figsize=(9,7))
ax.plot(data_sorted[data_sorted['marital']=='single']['age'], data_sorted[data_sorted['marital']=='single']['campaign'],'y')

ax.set(xlabel='Edad', ylabel='veces contactado',
       title='cantidad de veces contactado personas solteras')
plt.show()
fig, ax = plt.subplots(figsize=(9,7))
ax.plot(data_sorted[data_sorted['marital']=='married']['age'], data_sorted[data_sorted['marital']=='married']['campaign'],'b')

ax.set(xlabel='Edad', ylabel='veces contactado',
       title='cantidad de veces contactado personas casados')
plt.show()

fig, ax = plt.subplots(figsize=(9,7))
ax.plot(data_sorted[data_sorted['marital']=='divorced']['age'], data_sorted[data_sorted['marital']=='divorced']['campaign'],'r')

ax.set(xlabel='Edad', ylabel='veces contactado',
       title='cantidad de veces contactado personas divorciado o viudo')
plt.show()

#tres junto
fig, ax = plt.subplots(figsize=(9,7))
ax.plot(data_sorted[data_sorted['marital']=='divorced']['age'], data_sorted[data_sorted['marital']=='divorced']['campaign'],'r',data_sorted[data_sorted['marital']=='married']['age'], data_sorted[data_sorted['marital']=='married']['campaign'],'b',data_sorted[data_sorted['marital']=='single']['age'], data_sorted[data_sorted['marital']=='single']['campaign'],'y')

ax.set(xlabel='Edad', ylabel='veces contactado',
       title='compara las tres graficas')
ax.legend(['divorced','married','single'])
plt.show()

# %%
#primera fila segunda columna tercera selecciona grafico 1 o2
plt.subplots(2,2,figsize=(10,10))
plt.subplot(2,1, 1)
plt.plot(data_sorted[(data_sorted['marital']=='single') & (data_sorted['y']=='yes')]['age'],data_sorted[(data_sorted['marital']=='single')&(data_sorted['y']=='yes')]['campaign'],'--r',)
plt.title('cantida de contacto con term deposit')
plt.xlabel('Edad single')
plt.ylabel('veces contactado')

plt.subplot(2,1, 2)
plt.plot(data_sorted[(data_sorted['marital']=='married') & (data_sorted['y']=='yes')]['age'],data_sorted[(data_sorted['marital']=='married')&(data_sorted['y']=='yes')]['campaign'],'--b',)
plt.xlabel('Edad married')
plt.ylabel('veces contactado')
# Out:
# Text(0,0.5,'veces contactado')

# %%
soltero = pd.DataFrame()
soltero = soltero.append(data[(data['age']<20) & (data['marital']=='single') ][['campaign']].mean(),ignore_index=True)
soltero = soltero.append(data[((data['age']>=20) & (data['age']<30)) & (data['marital']=='single')][['campaign']].mean(),ignore_index=True)
soltero = soltero.append(data[((data['age']>=30) & (data['age']<40)) & (data['marital']=='single')][['campaign']].mean(),ignore_index=True)
soltero = soltero.append(data[((data['age']>=40) & (data['age']<50)) & (data['marital']=='single')][['campaign']].mean(),ignore_index=True) 
soltero = soltero.append(data[((data['age']>=50) & (data['age']<60)) & (data['marital']=='single')][['campaign']].mean(),ignore_index=True)
soltero = soltero.append(data[((data['age']>=60) & (data['age']<70)) & (data['marital']=='single')][['campaign']].mean(),ignore_index=True)
soltero = soltero.append(data[(data['age']>=70) & (data['marital']=='single')][['campaign']].mean(),ignore_index=True)

casado= pd.DataFrame()
casado = casado.append(data[(data['age']<20) & (data['marital']=='married')][['campaign']].mean(),ignore_index=True)
casado = casado.append(data[((data['age']>=20) & (data['age']<30)) & (data['marital']=='married')][['campaign']].mean(),ignore_index=True)
casado = casado.append(data[((data['age']>=30) & (data['age']<40)) & (data['marital']=='married')][['campaign']].mean(),ignore_index=True)
casado = casado.append(data[((data['age']>=40) & (data['age']<50)) & (data['marital']=='married')][['campaign']].mean(),ignore_index=True) 
casado = casado.append(data[((data['age']>=50) & (data['age']<60)) & (data['marital']=='married')][['campaign']].mean(),ignore_index=True)
casado = casado.append(data[((data['age']>=60) & (data['age']<70)) & (data['marital']=='married')][['campaign']].mean(),ignore_index=True)
casado = casado.append(data[(data['age']>=70) & (data['marital']=='married')][['campaign']].mean(),ignore_index=True)

divorciado= pd.DataFrame()
divorciado = divorciado.append(data[(data['age']<20) & (data['marital']=='divorced')][['campaign']].mean(),ignore_index=True)
divorciado = divorciado.append(data[((data['age']>=20) & (data['age']<30)) & (data['marital']=='divorced')][['campaign']].mean(),ignore_index=True)
divorciado = divorciado.append(data[((data['age']>=30) & (data['age']<40)) & (data['marital']=='divorced')][['campaign']].mean(),ignore_index=True)
divorciado = divorciado.append(data[((data['age']>=40) & (data['age']<50)) & (data['marital']=='divorced')][['campaign']].mean(),ignore_index=True) 
divorciado = divorciado.append(data[((data['age']>=50) & (data['age']<60)) & (data['marital']=='divorced')][['campaign']].mean(),ignore_index=True)
divorciado = divorciado.append(data[((data['age']>=60) & (data['age']<70)) & (data['marital']=='divorced')][['campaign']].mean(),ignore_index=True)
divorciado = divorciado.append(data[(data['age']>=70) & (data['marital']=='divorced')][['campaign']].mean(),ignore_index=True)



sol = np.arange(soltero['campaign'].count())



fig, ax = plt.subplots(figsize=(10,10))
ax.bar(sol,soltero['campaign'],width=0.2,color='b',align='center',label='single')
ax.bar(sol+0.3,casado['campaign'],width=0.2,color='y',align='center',label='married')
ax.bar(sol+0.6,divorciado['campaign'],width=0.2,color='r',align='center',label='divorced')

ax.set(ylabel='promedio', xlabel='edad',
       title='promedio de llamadas por edad y estado civil')

ax.set_xticklabels(('<30', '35', '45', '55', '60','65','70>'))
ax.legend(loc='best')
plt.show()

# %%
rango_edades = '<30', '35', '45', '55', '60','65','70>'
plt.plot()
plt.plot(rango_edades,soltero,'b--o',label='single')
plt.plot(rango_edades,casado,'y--o',label='single')
plt.plot(rango_edades,divorciado,'g--o',label='single')
plt.title('contactos promedio por rango de años ')
plt.xlabel('rango de años')
plt.ylabel('promedio de contactos')
plt.legend(loc='best')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-201-47494239fecb> in <module>()
#       7 plt.xlabel('rango de años')
#       8 plt.ylabel('promedio de contactos')
# ----> 9 plt.legend(loc='best')
#      10 plt.show()
#
# TypeError: 'list' object is not callable

# %% [markdown]
# En este grafico de desperdicio separe en nivel educacional "education"(primary,secondary,tertiary), obteniendo la edad y el balance anual en euros por persona.
# Como se puede ver en el grafico  la gran mayoría esta bajo los 30000 en balance anual  y que los que tienen el salario mas alto están entre 50 a 60 años y nivel de educación entre secondary y tertiary.

# %%
sd1 = data[data['education']=='primary'][['age','balance']]
sd2 = data[data['education']=='secondary'][['age','balance']]
sd3 = data[data['education']=='tertiary'][['age','balance']]
plt.scatter(sd1['age'], sd1['balance'], c='C1',label='primary')
plt.scatter(sd2['age'], sd2['balance'], c='C2',label='secondary')
plt.scatter(sd3['age'], sd3['balance'], c='C3',label='tertiary')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-204-31076411bd6c> in <module>()
#       5 plt.scatter(sd2['age'], sd2['balance'], c='C2',label='secondary')
#       6 plt.scatter(sd3['age'], sd3['balance'], c='C3',label='tertiary')
# ----> 7 plt.legend()
#       8 plt.show()
#
# TypeError: 'list' object is not callable

# %%
edu_pry= data[data['education']=='primary']['age']
edu_sec= data[data['education']=='secondary']['age']
edu_ter= data[data['education']=='tertiary']['age']
names = ['United Air Lines Inc.', 'JetBlue Airways', 'ExpressJet Airlines Inc']

colors = ['#E69F00', '#56B4E9', '#F0E442']

plt.hist([edu_pry, edu_sec,edu_ter], bins = int(180/15), normed=True,color = colors, label=names)

plt.xlabel('Delay (min)')
plt.ylabel('Normalized Flights')
plt.title('Side-by-Side Histogram with Multiple Airlines')
# Out:
# C:\Users\Diego\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# Text(0.5,1,'Side-by-Side Histogram with Multiple Airlines')
